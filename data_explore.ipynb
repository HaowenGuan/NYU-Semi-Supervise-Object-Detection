# %% [markdown]
# # Explore Dataset

# %%
import yaml
import cv2
import matplotlib.pyplot as plt

# i = [1, 30000]
i = 1

with open("dataset/labeled_data/training/labels/" + str(i) + ".yml", "r") as stream:
    try:
        label = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

img = cv2.imread("dataset/labeled_data/training/images/" + str(i) + ".JPEG")

# cv2.imshow('img', img)
plt.imshow(img)
plt.show()
